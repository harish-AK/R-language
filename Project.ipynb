# %%
df=read.csv("D:\\R studio/RStudio\\Programs\\archive\\life_expectancy_by_birth.csv")
df
# Out:
#     ï..ISO3 Country                            hdicode   region hdi_rank_2021
# 1   AFG     Afghanistan                        Low       SA     180
# 2   AGO     Angola                             Medium    SSA    148
# 3   ALB     Albania                            High      ECA     67
# 4   AND     Andorra                            Very High         40
# 5   ARE     United Arab Emirates               Very High AS      26
# 6   ARG     Argentina                          Very High LAC     47
# 7   ARM     Armenia                            High      ECA     85
# 8   ATG     Antigua and Barbuda                High      LAC     71
# 9   AUS     Australia                          Very High          5
# 10  AUT     Austria                            Very High         25
# 11  AZE     Azerbaijan                         High      ECA     91
# 12  BDI     Burundi                            Low       SSA    187
# 13  BEL     Belgium                            Very High         13
# ...

# %%
na_counts = colSums(is.na(df))
print(na_counts)
# Out:
#       ï..ISO3       Country       hdicode        region hdi_rank_2021
#             0             0             0             0            15
#       le_1990       le_1991       le_1992       le_1993       le_1994
#             0             0             0             0             0
#       le_1995       le_1996       le_1997       le_1998       le_1999
#             0             0             0             0             0
#       le_2000       le_2001       le_2002       le_2003       le_2004
#             0             0             0             0             0
#       le_2005       le_2006       le_2007       le_2008       le_2009
#             0             0             0             0             0
#       le_2010       le_2011       le_2012       le_2013       le_2014
#             0             0             0             0             0
#       le_2015       le_2016       le_2017       le_2018       le_2019
# ...

# %%
# Remove multiple columns by specifying the column indices
df = df[, -c(6:28)]

# %%
df
# Out:
#     ï..ISO3 Country                            hdicode   region hdi_rank_2021
# 1   AFG     Afghanistan                        Low       SA     180
# 2   AGO     Angola                             Medium    SSA    148
# 3   ALB     Albania                            High      ECA     67
# 4   AND     Andorra                            Very High         40
# 5   ARE     United Arab Emirates               Very High AS      26
# 6   ARG     Argentina                          Very High LAC     47
# 7   ARM     Armenia                            High      ECA     85
# 8   ATG     Antigua and Barbuda                High      LAC     71
# 9   AUS     Australia                          Very High          5
# 10  AUT     Austria                            Very High         25
# 11  AZE     Azerbaijan                         High      ECA     91
# 12  BDI     Burundi                            Low       SSA    187
# 13  BEL     Belgium                            Very High         13
# ...

# %%
mean = mean(df$le_2021)

median= median(df$le_2021)

sd = sd(df$le_2021)

var = var(df$le_2021)

# %%
mean
median
sd
var
# Out:
# [1] 71.2215
# [1] 71.6881
# [1] 7.643726
# [1] 58.42654

# %%
names(df)[names(df) == "ï..ISO3"] <- "ISO3"

# %%
df  =df[-(196:206),]
df
# Out:
#     ISO3 Country                            hdicode   region hdi_rank_2021
# 1   AFG  Afghanistan                        Low       SA     180
# 2   AGO  Angola                             Medium    SSA    148
# 3   ALB  Albania                            High      ECA     67
# 4   AND  Andorra                            Very High         40
# 5   ARE  United Arab Emirates               Very High AS      26
# 6   ARG  Argentina                          Very High LAC     47
# 7   ARM  Armenia                            High      ECA     85
# 8   ATG  Antigua and Barbuda                High      LAC     71
# 9   AUS  Australia                          Very High          5
# 10  AUT  Austria                            Very High         25
# 11  AZE  Azerbaijan                         High      ECA     91
# 12  BDI  Burundi                            Low       SSA    187
# 13  BEL  Belgium                            Very High         13
# ...

# %%
library(dplyr)
df = df %>%mutate(region = ifelse(region == "", "Unknown", region))
df
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#     ISO3 Country                            hdicode   region  hdi_rank_2021
# 1   AFG  Afghanistan                        Low       SA      180
# 2   AGO  Angola                             Medium    SSA     148
# 3   ALB  Albania                            High      ECA      67
# 4   AND  Andorra                            Very High Unknown  40
# 5   ARE  United Arab Emirates               Very High AS       26
# 6   ARG  Argentina                          Very High LAC      47
# 7   ARM  Armenia                            High      ECA      85
# 8   ATG  Antigua and Barbuda                High      LAC      71
# 9   AUS  Australia                          Very High Unknown   5
# 10  AUT  Austria                            Very High Unknown  25
# ...

# %%
na_counts = colSums(is.na(df))
print(na_counts)
# Out:
#          ISO3       Country       hdicode        region hdi_rank_2021
#             0             0             0             0             4
#       le_2013       le_2014       le_2015       le_2016       le_2017
#             0             0             0             0             0
#       le_2018       le_2019       le_2020       le_2021
#             0             0             0             0

# %%
df = df %>%mutate(hdi_rank_2021 = ifelse(hdi_rank_2021 == "", "Unknown", hdi_rank_2021))
df
# Out:
#     ISO3 Country                            hdicode   region  hdi_rank_2021
# 1   AFG  Afghanistan                        Low       SA      180
# 2   AGO  Angola                             Medium    SSA     148
# 3   ALB  Albania                            High      ECA      67
# 4   AND  Andorra                            Very High Unknown  40
# 5   ARE  United Arab Emirates               Very High AS       26
# 6   ARG  Argentina                          Very High LAC      47
# 7   ARM  Armenia                            High      ECA      85
# 8   ATG  Antigua and Barbuda                High      LAC      71
# 9   AUS  Australia                          Very High Unknown   5
# 10  AUT  Austria                            Very High Unknown  25
# 11  AZE  Azerbaijan                         High      ECA      91
# 12  BDI  Burundi                            Low       SSA     187
# 13  BEL  Belgium                            Very High Unknown  13
# ...

# %%
# label encoding for the column hdicode
df$hdicode <- as.integer(factor(df$hdicode, ordered = TRUE))

# %%
df
# Out:
#     ISO3 Country                            hdicode region  hdi_rank_2021
# 1   AFG  Afghanistan                        3       SA      180
# 2   AGO  Angola                             4       SSA     148
# 3   ALB  Albania                            2       ECA      67
# 4   AND  Andorra                            5       Unknown  40
# 5   ARE  United Arab Emirates               5       AS       26
# 6   ARG  Argentina                          5       LAC      47
# 7   ARM  Armenia                            2       ECA      85
# 8   ATG  Antigua and Barbuda                2       LAC      71
# 9   AUS  Australia                          5       Unknown   5
# 10  AUT  Austria                            5       Unknown  25
# 11  AZE  Azerbaijan                         2       ECA      91
# 12  BDI  Burundi                            3       SSA     187
# 13  BEL  Belgium                            5       Unknown  13
# 14  BEN  Benin                              3       SSA     166
# ...

# %%
# one_hot_encoded
df1=read.csv("D:\\R studio/RStudio\\Programs\\archive\\life_expectancy_by_birth.csv")

one_hot_encoded = model.matrix(~ 0 + hdicode, data = df1)

one_hot_df = as.data.frame(one_hot_encoded)

df1 = cbind(df1, one_hot_df)

df1 = df1[, !(names(df) %in% c("hdicode"))]

df1
# Out:
#     ï..ISO3 Country                            region hdi_rank_2021 le_1990
# 1   AFG     Afghanistan                        SA     180           45.9672
# 2   AGO     Angola                             SSA    148           41.8933
# 3   ALB     Albania                            ECA     67           73.1439
# 4   AND     Andorra                                    40           78.4063
# 5   ARE     United Arab Emirates               AS      26           71.9004
# 6   ARG     Argentina                          LAC     47           71.7837
# 7   ARM     Armenia                            ECA     85           68.8209
# 8   ATG     Antigua and Barbuda                LAC     71           73.4922
# 9   AUS     Australia                                   5           77.0443
# 10  AUT     Austria                                    25           75.7396
# 11  AZE     Azerbaijan                         ECA     91           62.3522
# ...
